# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
Result = arr ** 2 #vectrized operation

# %%
Result
# Out:
# array([ 1,  4,  9, 16, 25])

# %%
Result1 = arr + 10

# %%
Result1
# Out:
# array([11, 12, 13, 14, 15])

# %%
arr1 = np.array([[1, 2, 3], [4, 5, 6]])

# %%
arr2 = np.array([11, 22, 33])

# %%
result = arr1 + arr2

# %%
result
# Out:
# array([[12, 24, 36],
#        [15, 27, 39]])
