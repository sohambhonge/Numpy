# %%
import numpy as np

# %%
arr = np.array([2, 3, 5, 7, 10])

# %%
np.mean(arr)
# Out:
# np.float64(5.4)

# %%
np.max(arr)
# Out:
# np.int64(10)

# %%
np.min(arr)
# Out:
# np.int64(2)

# %%
np.std(arr)
# Out:
# np.float64(2.870540018881465)

# %%
np.var(arr)
# Out:
# np.float64(8.24)

# %%
np.sum(arr)
# Out:
# np.int64(27)

# %%
np.prod(arr)
# Out:
# np.int64(2100)

# %%
np.median(arr)
# Out:
# np.float64(5.0)

# %%
np.percentile(arr, 75)
# Out:
# np.float64(7.0)

# %%
np.argmin(arr) #smallest element index inside the array
# Out:
# np.int64(0)

# %%
np.argmax(arr) #largest element index inside the array
# Out:
# np.int64(4)

# %%
arr2 = np.array([2, 3, 5, 17, 60, 2, 17, 3])

# %%
np.unique(arr2)
# Out:
# array([ 2,  3,  5, 17, 60])

# %%
np.diff(arr2)
# Out:
# array([  1,   2,  12,  43, -58,  15, -14])

# %%
np.cumsum(arr2)
# Out:
# array([  2,   5,  10,  27,  87,  89, 106, 109])

# %%
np.linspace(0, 10, 20)
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
np.log(arr2)
# Out:
# array([0.69314718, 1.09861229, 1.60943791, 2.83321334, 4.09434456,
#        0.69314718, 2.83321334, 1.09861229])

# %%
np.exp(arr2)
# Out:
# array([7.38905610e+00, 2.00855369e+01, 1.48413159e+02, 2.41549528e+07,
#        1.14200739e+26, 7.38905610e+00, 2.41549528e+07, 2.00855369e+01])
